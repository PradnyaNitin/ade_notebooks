-- %%
--select * from emp

-- %%
use sql_catalog.sql_schema;
show tables;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>sql_schema</td><td>dept</td><td>false</td></tr><tr><td>sql_schema</td><td>emp</td><td>false</td></tr><tr><td>sql_schema</td><td>salgrade</td><td>false</td></tr></tbody></table></div>

-- %%
select * from dept;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td></tr><tr><td>40</td><td>OPERATIONS</td><td>BOSTON</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.31. List	all	the	emps	who	joined	before	or	after	1981.

-- %%
select * from emp
where year(hiredate) != '1981';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
SELECT * FROM emp WHERE YEAR(hiredate) <> 1981;
--OR SELECT * FROM emp WHERE YEAR(hiredate) != 1981;
--OR SELECT * FROM emp WHERE YEAR(hiredate) not like 1981;
--OR SELECT * FROM emp WHERE YEAR(hiredate) not in 1981;

-- %% [markdown]
-- #### 2.32. List	the	emps	whose	Empno	not	starting	with	digit78.

-- %%
select * from emp
where empno not like '78%';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.33. List	the	emps	who	are	working	under	‘MGR’

-- %%
 select * from emp;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
select * from emp where job = 'MANAGER';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
SELECT e.empno,
       e.ename,
       e.job,
       e.mgr
FROM emp e
JOIN emp m
  ON e.mgr = m.empno
WHERE m.job = 'MANAGER';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td></tr></tbody></table></div>

-- %%
SELECT e.empno, e.ename, e.job, e.mgr, e.hiredate, e.sal, e.comm, e.deptno
FROM emp e
JOIN emp m ON e.mgr = m.empno
WHERE m.job = 'MGR';

/*
--Note- if we write m.mgr = e.empno then its not correct
You're joining on m.mgr = e.empno, which means you're trying to find employees who are managers of someone whose manager is them — this logic is reversed.
You're essentially saying: “Find employees who are managers of managers whose job is 'MGR'”, which is not what you want.
This correctly:

Joins each employee e to their manager m using e.mgr = m.empno.
*/
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### 2.34.List	the	emps	who	joined	in	any	year	but	not	belongs	to	the	month	of March.

-- %%
select * from emp 
where month(hiredate) != 3;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
SELECT empno, ename, job, mgr, hiredate, sal, comm, deptno
FROM emp
WHERE MONTH(hiredate) <> 3;

--OR select * from emp where date_format(hiredate, 'MMMM') <> 'March'

--OR select * from emp WHERE date_format(CAST(hiredate AS DATE), 'MMMM') <> 'March';

-- %% [markdown]
-- #### 2.35. List	all	the	Clerks of	Deptno	20.

-- %%
select * from emp
where job = 'CLERK' and deptno = 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %%
select * from emp where job = 'CLERK' and deptno = 20

-- %% [markdown]
-- #### 2.36. List	the	emps	of	Deptno	30	or	10	joined	in	the	year	1981

-- %%
select * from emp
where deptno = 30 or deptno = 10 and year(hiredate) = 1981;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr></tbody></table></div>

-- %%
select * from emp where deptno =  30 or deptno = 10 and year(hiredate) = 1981

-- %% [markdown]
-- #### 2.37.Display	the	details	of	SMITH.

-- %%
select * from emp where ename = 'SMITH';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %%
select * from emp where ename = 'SMITH'

-- %% [markdown]
-- #### 2.38. Display	the	location	of SMITH.

-- %%
select ename, loc from emp e
join dept d
on e.deptno = d.deptno
where e.ename = 'SMITH';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>loc</th></tr></thead><tbody><tr><td>SMITH</td><td>DALLAS</td></tr></tbody></table></div>

-- %%
select loc from emp e
join dept d
on e.deptno = d.deptno
where e.ename = 'SMITH'

-- %% [markdown]
-- #### 2.39. List	the	total	information	of	EMP	table	along	with	DNAME	and	Loc	of all	the	emps	Working	Under	‘ACCOUNTING’	&	‘RESEARCH’	in	the	asc Deptno.

-- %%
select e.*, d.dname,d.loc from emp e 
join dept d 
on e.deptno = d.deptno
where d.dname = 'ACCOUNTING' or d.dname= 'RESEARCH'
order by d.deptno;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr></tbody></table></div>

-- %%
select e.empno, e.ename, e.job, d.dname, d.loc from emp e
join dept d
on e.deptno = d.deptno
where d.dname in ('ACCOUNTING', 'RESEARCH') order by d.deptno asc

-- %% [markdown]
-- ####  2.40.	List	the	Empno,	Ename,	Sal,	Dname	of	all	the	‘MGRS’	and	‘ANALYST’ working	in	New	York,	Dallas	with	an	exp	more	than	7	years	without	receiving the	Comm	asc	order	of	Loc.

-- %%
SELECT e.empno, e.ename, e.sal, d.dname, e.job, d.loc
FROM emp e
JOIN dept d ON e.deptno = d.deptno
WHERE e.job IN ('MANAGER', 'ANALYST')
  AND d.loc IN ('New York', 'Dallas')
  AND (YEAR(current_date()) - YEAR(e.hiredate)) > 7
  AND e.comm IS NULL
ORDER BY d.loc ASC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>sal</th><th>dname</th><th>job</th><th>loc</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### 2.41. Display	the	Empno,	Ename,	Sal,	Dname,	Loc,	Deptno,	Job	of	all	emps working	at	CJICAGO	or	working	for	ACCOUNTING	dept	with	Ann Sal>28000,	but	the	Sal	should	not	be=3000	or	2800	who	doesn’t	belongs	to	the Mgr	and	whose	no	is	having	a	digit	‘7’	or	‘8’	in	3rd	position	in	the	asc	order	of Deptno	and	desc	order	of	job

-- %%
--Method 1
select e.empno, e.ename, e.sal, d.dname, d.loc, e.deptno, e.job
from emp e join dept d
on e.deptno = d.deptno
where d.loc = 'CHICAGO' or d.dname = 'ACCOUNTING'
and e.sal*12 > 28000 and e.sal != 3000 or e.sal != 2800 
and e.job <> 'Manager'
and substring(e.empno, 3,1) in ('7','8') 
order by e.deptno asc, e.job desc
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>sal</th><th>dname</th><th>loc</th><th>deptno</th><th>job</th></tr></thead><tbody><tr><td>7839</td><td>KING</td><td>5000</td><td>ACCOUNTING</td><td>NEW YORK</td><td>10</td><td>PRESIDENT</td></tr><tr><td>7782</td><td>CLARK</td><td>2450</td><td>ACCOUNTING</td><td>NEW YORK</td><td>10</td><td>MANAGER</td></tr><tr><td>7876</td><td>ADAMS</td><td>1100</td><td>RESEARCH</td><td>DALLAS</td><td>20</td><td>CLERK</td></tr><tr><td>7788</td><td>SCOTT</td><td>3000</td><td>RESEARCH</td><td>DALLAS</td><td>20</td><td>ANALYST</td></tr><tr><td>7844</td><td>TURNER</td><td>1500</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>SALESMAN</td></tr><tr><td>7521</td><td>WARD</td><td>1250</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>SALESMAN</td></tr><tr><td>7654</td><td>MARTIN</td><td>1250</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>SALESMAN</td></tr><tr><td>7499</td><td>ALLEN</td><td>1600</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>SALESMAN</td></tr><tr><td>7698</td><td>BLAKE</td><td>2850</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>MANAGER</td></tr><tr><td>7900</td><td>JAMES</td><td>950</td><td>SALES</td><td>CHICAGO</td><td>30</td><td>CLERK</td></tr></tbody></table></div>

-- %%
--Method 2
select e.empno, e.ename, e.sal, d.dname, d.loc, e.deptno, e.job
from emp e join dept d
on e.deptno = d.deptno
where d.loc = 'CHICAGO' or d.dname = 'ACCOUNTING'
and e.sal*12 > 28000 and e.sal != 3000 or e.sal != 2800 
and e.job <> 'Manager'
and substring(cast(e.empno as string), 3,1) in ('7','8') 
order by e.deptno asc, e.job desc

-- %%
--Method 3
select e.empno, e.ename, e.sal, d.dname, d.loc, e.deptno, e.job
from emp e join dept d
on e.deptno = d.deptno
where (d.loc = 'CHICAGO' or d.dname = 'ACCOUNTING')
and e.sal*12 > 28000 and e.sal != 3000 or e.sal != 2800 
and e.job <> 'Manager'
and e.empno like '__7%' or e.empno like '__8%'
order by e.deptno asc, e.job desc

-- %%
CREATE TABLE salgrade (
    grade INT,
    losal INT,
    hisal INT
);

INSERT INTO salgrade VALUES (1, 700, 1200);
INSERT INTO salgrade VALUES (2, 1201, 1400);
INSERT INTO salgrade VALUES (3, 1401, 2000);
INSERT INTO salgrade VALUES (4, 2001, 3000);
select * from salgrade;

-- %%
select * from salgrade
order by grade asc;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>1</td><td>700</td><td>1200</td></tr><tr><td>2</td><td>1201</td><td>1400</td></tr><tr><td>3</td><td>1401</td><td>2000</td></tr><tr><td>4</td><td>2001</td><td>3000</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.42. Display	the	total	information	of	the	emps	along	with	Grades	in	the	asc order.

-- %%
-- Non-equi join:
/*
e.salary BETWEEN s.losal AND s.hisal

Match based on a range/condition  */

SELECT *
FROM emp e
LEFT JOIN salgrade s   -- left join to include all employees including president
  ON e.sal BETWEEN s.losal AND s.hisal
ORDER BY grade ASC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td><td>4</td><td>2001</td><td>3000</td></tr></tbody></table></div>

-- %%
select	*	from	emp	e	,salgrade	s	
where	e.sal	between	s.losal	and	s.hisal		
order by grade	asc;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td><td>4</td><td>2001</td><td>3000</td></tr></tbody></table></div>

-- %%
select * from emp;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
select * from emp e, salgrade s
where e.sal > s.losal and e.sal < s.hisal
order by s.grade asc
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td><td>4</td><td>2001</td><td>3000</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.43. List	all	the	Grade2	and	Grade	3	emps.

-- %%
select * from emp e, salgrade s 
where e.sal between s.losal and s.hisal
and s.grade in (2,3);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td><td>3</td><td>1401</td><td>2000</td></tr></tbody></table></div>

-- %%
select * from emp e, salgrade s where e.sal between s.losal and s.hisal and s.grade in (2,3)

-- %% [markdown]
-- #### 2.44. Display	all	Grade	4,5	Analyst	and	Mgr.

-- %%
select * from emp e, salgrade s
where e.sal between s.losal and s.hisal
and e.job in ('MANAGER', 'ANALYST')
and s.grade in (4,5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>4</td><td>2001</td><td>3000</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.45.	List	the	Empno,	Ename,	Sal,	Dname,	Grade,	Exp,	and	Ann	Sal	of	emps working	for	Dept10	or20.

-- %%
select * from emp e, dept d, salgrade s
where d.deptno in (10,20)
and e.sal between s.losal and s.hisal;
-- VIP . wrong way without join?
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>deptno</th><th>dname</th><th>loc</th><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>1</td><td>700</td><td>1200</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>4</td><td>2001</td><td>3000</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>3</td><td>1401</td><td>2000</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>2</td><td>1201</td><td>1400</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839 ...

-- %% [markdown]
-- ####  2.45.	List	the	Empno,	Ename,	Sal,	Dname,	Grade,	Exp,	and	Ann	Sal	of	emps working	for	Dept10	or20.

-- %%
select e.empno, e.ename, e.sal, d.dname,s.grade,d.deptno, year(current_date) - year(e.hiredate) as exp, (e.sal *12) as annual_sal

from emp e--, dept d, salgrade s
inner join dept d on e.deptno = d.deptno
inner join salgrade s on e.sal between losal and hisal
where d.deptno in (10,20)
order by d.deptno asc;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>sal</th><th>dname</th><th>grade</th><th>deptno</th><th>exp</th><th>annual_sal</th></tr></thead><tbody><tr><td>7782</td><td>CLARK</td><td>2450</td><td>ACCOUNTING</td><td>4</td><td>10</td><td>45</td><td>29400</td></tr><tr><td>7934</td><td>MILLER</td><td>1300</td><td>ACCOUNTING</td><td>2</td><td>10</td><td>44</td><td>15600</td></tr><tr><td>7566</td><td>JONES</td><td>2975</td><td>RESEARCH</td><td>4</td><td>20</td><td>45</td><td>35700</td></tr><tr><td>7902</td><td>FORD</td><td>3000</td><td>RESEARCH</td><td>4</td><td>20</td><td>45</td><td>36000</td></tr><tr><td>7369</td><td>SMITH</td><td>800</td><td>RESEARCH</td><td>1</td><td>20</td><td>46</td><td>9600</td></tr><tr><td>7876</td><td>ADAMS</td><td>1100</td><td>RESEARCH</td><td>1</td><td>20</td><td>43</td><td>13200</td></tr><tr><td>7788</td><td>SCOTT</td><td>3000</td><td>RESEARCH</td><td>4</td><td>20</td><td>44</td><td>36000</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.46. List	all	the	information	of	emp	with	Loc	and	the	Grade	of	all	the	emps belong	to	the	Grade	range	from	2	to	4	working	at	the	Dept	those	are	not	starting with	char	set	‘OP’	and	not	ending	with	‘S’	with	the	designation	having	a	char	‘a’ any	where	joined	in	the	year	1981	but	not	in	the	month	of	Mar	or	Sep	and	Sal not	end	with	‘00’	in	the	asc	order	of	Grades

-- %%
select e.empno, e.ename, e.job, e.hiredate, e.sal,e.deptno, d.loc, s.grade 
from emp e
join dept d  on e.deptno = d.deptno
join salgrade s on e.sal between s.losal and s.hisal
where s.grade in (2,3,4)

 -- and d.dname not in ("OP%") and ('%S');
  and d.dname not like 'OP%'
  and d.dname not like '%S'
  and e.job ilike '%a%'  -- VIP ilike is case in-senstitive.
  and year(e.hiredate) = 1981
  and month(e.hiredate) not in (3,9)
  and cast(e.sal as string) not like '%00'
order by s.grade asc ;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>hiredate</th><th>sal</th><th>deptno</th><th>loc</th><th>grade</th></tr></thead><tbody><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>1981-06-09</td><td>2450</td><td>10</td><td>NEW YORK</td><td>4</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>1981-04-02</td><td>2975</td><td>20</td><td>DALLAS</td><td>4</td></tr></tbody></table></div>

-- %%
select * from salgrade;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>grade</th><th>losal</th><th>hisal</th></tr></thead><tbody><tr><td>3</td><td>1401</td><td>2000</td></tr><tr><td>4</td><td>2001</td><td>3000</td></tr><tr><td>1</td><td>700</td><td>1200</td></tr><tr><td>2</td><td>1201</td><td>1400</td></tr></tbody></table></div>

-- %%
--Method 1
SELECT e.empno, e.ename, e.job, e.sal, e.hiredate, d.loc, s.grade
FROM emp e
JOIN dept d ON e.deptno = d.deptno
JOIN salgrade s ON e.sal BETWEEN s.losal AND s.hisal
WHERE s.grade IN (2, 3, 4)
  AND d.dname NOT LIKE 'OP%'
  AND d.dname NOT LIKE '%S'
  AND e.job ILIKE '%a%'                -- designation contains 'a'
  AND YEAR(e.hiredate) = 1981          -- joined in 1981
  AND MONTH(e.hiredate) NOT IN (3, 9)  -- not March or September
  AND CAST(e.sal AS STRING) NOT LIKE '%00' -- salary not ending with 00
ORDER BY s.grade ASC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>sal</th><th>hiredate</th><th>loc</th><th>grade</th></tr></thead><tbody><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>2450</td><td>1981-06-09</td><td>NEW YORK</td><td>4</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>2975</td><td>1981-04-02</td><td>DALLAS</td><td>4</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.47 List	the	details	of	the	Depts	along	with	Empno,	Ename	or	without	the emps

-- %%
use sql_catalog.sql_schema;
select * from dept;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td></tr><tr><td>40</td><td>OPERATIONS</td><td>BOSTON</td></tr></tbody></table></div>

-- %%
SELECT d.*, e.empno, e.ename
FROM Dept d
LEFT JOIN Emp e
ON d.deptno = e.deptno
ORDER BY d.deptno;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>dname</th><th>loc</th><th>empno</th><th>ename</th></tr></thead><tbody><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>7934</td><td>MILLER</td></tr><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>7782</td><td>CLARK</td></tr><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td><td>7839</td><td>KING</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>7369</td><td>SMITH</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>7876</td><td>ADAMS</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>7788</td><td>SCOTT</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>7566</td><td>JONES</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td><td>7902</td><td>FORD</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7698</td><td>BLAKE</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7499</td><td>ALLEN</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7654</td><td>MARTIN</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7521</td><td>WARD</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7844</td><td>TURNER</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td><td>7900</td><td>JAMES</td></tr><tr><td>40</td><td>OPERATIONS</td><td>BOSTON</td><td>null</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.48 List	the	details	of	the	emps	whose	Salaries	more	than	the	employee BLAKE.

-- %%
select * from emp
where sal > (select sal from emp where ename = 'BLAKE')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %%
select * from emp where sal > (select sal from emp where ename = 'BLAKE')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.49.List	the	emps	whose	Jobs	are	same	as	ALLEN.

-- %%
select * from emp
where (job ) in (select job from emp where ename = 'ALLEN');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr></tbody></table></div>

-- %%
SELECT * FROM EMP WHERE JOB = (SELECT job from emp where ename = 'ALLEN')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.50. List	the	emps	who	are	senior	to	King.

-- %%
select * from emp where hiredate>(select hiredate from emp where ename = 'KING')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.51.	List	the	Emps	who	are	senior	to	their	own	MGRS.

-- %%
SELECT
    e.empno AS EmployeeNo,
    e.ename AS EmployeeName,
    e.hiredate AS EmployeeHireDate,
    m.empno AS ManagerNo,
    m.ename AS ManagerName,
    m.hiredate AS ManagerHireDate
FROM Emp e
JOIN Emp m
ON e.mgr = m.empno
WHERE e.hiredate < m.hiredate
ORDER BY e.hiredate;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmployeeNo</th><th>EmployeeName</th><th>EmployeeHireDate</th><th>ManagerNo</th><th>ManagerName</th><th>ManagerHireDate</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>1980-12-17</td><td>7902</td><td>FORD</td><td>1981-12-03</td></tr><tr><td>7499</td><td>ALLEN</td><td>1981-02-20</td><td>7698</td><td>BLAKE</td><td>1981-05-01</td></tr><tr><td>7521</td><td>WARD</td><td>1981-02-22</td><td>7698</td><td>BLAKE</td><td>1981-05-01</td></tr><tr><td>7566</td><td>JONES</td><td>1981-04-02</td><td>7839</td><td>KING</td><td>1981-11-17</td></tr><tr><td>7698</td><td>BLAKE</td><td>1981-05-01</td><td>7839</td><td>KING</td><td>1981-11-17</td></tr><tr><td>7782</td><td>CLARK</td><td>1981-06-09</td><td>7839</td><td>KING</td><td>1981-11-17</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.52.List	the	Emps	of	Deptno	20	whose	Jobs	are	same	as	Deptno10.

-- %%
select * from emp 
where deptno = 20 
and job in (select job from emp where deptno = 10);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %%
select empno, ename, job, deptno from emp where deptno = 20 
and job in (select job from emp where deptno = 10)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>20</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>20</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.53.List	the	Emps	whose	Sal	is	same	as	FORD	or	SMITH	in	desc	order	of Sal.

-- %%
select * from emp
where sal in (select sal from emp where ename in ('FORD', 'SMITH'));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %%
select * from emp where sal in (select sal from emp where (ename = 'FORD' or ename = 'SMITH')) order by sal desc
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2.54. List	the	emps	Whose	Jobs	are	same	as	MILLER	or	Sal	is	more	than ALLEN.

-- %%
select * from emp
where job in (select job where ename = 'MILLER') or sal > (select sal from emp where ename  = 'ALLEN');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
select * from emp where job in(select job from emp where ename = 'MILLER') 
or sal >(select sal from emp where ename = 'ALLEN')

-- %% [markdown]
-- #### 2.55. List	the	Emps	whose	Sal	is	>	the	total	remuneration	of	the	SALESMAN.

-- %%
SELECT *
FROM emp 
WHERE sal > (
    SELECT SUM(sal + COALESCE(comm, 0)) AS total_remuneration
    FROM emp 
    WHERE job = 'SALESMAN'
);

/*
sal: This is the employee's base salary.
comm: This is the commission (extra earnings), which can be NULL for many employees.
COALESCE(comm, 0):

COALESCE is a SQL function that returns the first non-NULL value from its arguments.
So if comm is NULL, it will return 0 instead.
This prevents errors and ensures the calculation works even when commission is missing.

*/
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ####  2.56.	List	the	emps	who	are	senior	to	BLAKE	working	at	CHICAGO	& BOSTON.

-- %%
use sql_catalog.sql_schema;
select * from dept;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>10</td><td>ACCOUNTING</td><td>NEW YORK</td></tr><tr><td>20</td><td>RESEARCH</td><td>DALLAS</td></tr><tr><td>30</td><td>SALES</td><td>CHICAGO</td></tr><tr><td>40</td><td>OPERATIONS</td><td>BOSTON</td></tr></tbody></table></div>

-- %%
select * from emp e
join dept d on e.deptno = d.deptno
where e.hiredate < (select hiredate from emp where ename = 'BLAKE')
and d.loc in ('CHICAGO','BOSTON');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th><th>deptno</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td><td>30</td><td>SALES</td><td>CHICAGO</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td><td>30</td><td>SALES</td><td>CHICAGO</td></tr></tbody></table></div>

-- %%
SELECT
    e.empno,
    e.ename,
    e.job,
    e.hiredate,
    d.dname,
    d.loc
FROM Emp e
JOIN Dept d ON e.deptno = d.deptno
WHERE e.hiredate < (
    SELECT hiredate 
    FROM Emp 
    WHERE ename = 'BLAKE'
)
AND d.loc IN ('CHICAGO', 'BOSTON')
ORDER BY e.hiredate;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>hiredate</th><th>dname</th><th>loc</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>1981-02-20</td><td>SALES</td><td>CHICAGO</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>1981-02-22</td><td>SALES</td><td>CHICAGO</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.57.	List	the	Emps	of	Grade	3,4	belongs	to	the	dept	ACCOUNTING	and RESEARCH	whose	Sal	is	more	than	ALLEN	and	exp	more	than	SMITH	in	the asc	order	of	EXP.

-- %%
SELECT e.empno, e.ename, e.job, e.sal, e.hiredate, d.dname, s.grade
FROM Emp e
JOIN Dept d ON e.deptno = d.deptno
JOIN Salgrade s ON e.sal BETWEEN s.losal AND s.hisal
WHERE s.grade IN (3, 4)
  AND d.dname IN ('ACCOUNTING', 'RESEARCH')
  AND e.sal > (SELECT sal FROM Emp WHERE ename = 'ALLEN')
  AND e.hiredate < (SELECT hiredate FROM Emp WHERE ename = 'SMITH')
ORDER BY e.hiredate ASC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>sal</th><th>hiredate</th><th>dname</th><th>grade</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### 2.58. List	the	emps	whose	jobs	same	as	SMITH	or	ALLEN.

-- %%
select * from emp where job in (select job from emp where ename in( 'SMITH','ALLEN'));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %% [markdown]
-- ####  2.59.Write	a	Query	to	display	the	details	of	emps	whose	Sal	is	same	as	of
-- * 1-Employee	Sal	of	EMP1	table.
-- * 2-  ¾	Sal	of	any	Mgr	of	EMP2	table.
-- * 3- The	sal	of	any	person	with	exp	of	5	years	belongs	to	the	sales	dept	of	emp3 table.
-- * 4- Any	grade	2	employee	of	emp4	table.
-- * 5- Any	grade	2	and	3	employee	working	fro	sales	dept	or	operations	dept joined	in	89.

-- %%
use sql_catalog.sql_schema;
select * from emp
where sal in (select sal from emp);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-12-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-04-02</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839</td><td>1981-06-09</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1982-12-09</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1983-01-12</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-12-03</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
--Q1- 1-Employee Sal of EMP1 table.

select * from emp where sal in (select sal from emp1)
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-8586481273662126>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', '--Q1- 1-Employee Sal of EMP1 table.\n\nselect * from emp where sal in (select sal from emp1)\n')
--
-- File /databricks/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:152, in SqlMagic.sql(self, line, cell)
--     148     raise Exception(
--     149         "Cannot run %sql command because spark connect initialization failed and no stacktrace was available."
--     150     )
--     151 if self.use_py4j:
-- --> 152     return self.execute_via_py4j(cell)
--     154 return self.execute_via_sql_comm_handler(cell)
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:237, in SqlMagic.execute_via_py4j(self, cell)
--     234 except BaseException as e:
--     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     236                                                        json.dumps(get_debug_info(e)))
-- --> 237     raise e
--     238 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
--     239 return result
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:233, in SqlMagic.execute_via_py4j(self, cell)
--     231         print(f"Executing subquery: {query_text}.", file=sys.__stdout__)  # type: ignore
--     232         sql_directive = self.entry_point.getSqlDirective(query_text)
-- --> 233         result = self.handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
--     234 except BaseException as e:
--     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     236                                                        json.dumps(get_debug_info(e)))
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:257, in SqlMagic.handle_sql_directive(self, sql_directive, is_last_query)
--     254 query = sql_directive.sql()
--     255 self._register_udf_if_needed(
--     256     query, self.entry_point.escapeWidgetValues(self.dbutils.widgets.getAll()))
-- --> 257 df = self.get_query_request_result(query)
--     258 if df is None or len(df.schema) == 0:
--     259     # E.g. "create or replace temp view abc as select 1" gets us here and we should not return a result in this case.
--     260     return None
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:129, in SqlMagic.get_query_request_result(self, query)
--     127 if len(widget_bindings := self.dbutils.widgets.getAll()) > 0:
--     128     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
-- --> 129 df = self.asserting_spark.sql(query, widget_bindings)
--     130 return df
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/session.py:736, in SparkSession.sql(self, sqlQuery, args, **kwargs)
--     733         _views.append(SubqueryAlias(df._plan, name))
--     735 cmd = SQL(sqlQuery, _args, _named_args, _views)
-- --> 736 data, properties, ei = self.client.execute_command(cmd.command(self._client))
--     737 if "sql_command_result" in properties:
--     738     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1306, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
--    1304     req.user_context.user_id = self._user_id
--    1305 req.plan.command.CopyFrom(command)
-- -> 1306 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
--    1307     req, observations or {}, extra_request_metadata
--    1308 )
--    1309 # Create a query execution object.
--    1310 ei = ExecutionInfo(metrics, observed_metrics)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1762, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
--    1759 properties: Dict[str, Any] = {}
--    1761 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
-- -> 1762     for response in self._execute_and_fetch_as_iterator(
--    1763         req, observations, extra_request_metadata or [], progress=progress
--    1764     ):
--    1765         if isinstance(response, StructType):
--    1766             schema = response
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1738, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
--    1736     raise kb
--    1737 except Exception as error:
-- -> 1738     self._handle_error(error)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2054, in SparkConnectClient._handle_error(self, error)
--    2052 self.thread_local.inside_error_handling = True
--    2053 if isinstance(error, grpc.RpcError):
-- -> 2054     self._handle_rpc_error(error)
--    2055 elif isinstance(error, ValueError):
--    2056     if "Cannot invoke RPC" in str(error) and "closed" in str(error):
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2135, in SparkConnectClient._handle_rpc_error(self, rpc_error)
--    2131             d.Unpack(info)
--    2133             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
-- -> 2135             raise convert_exception(
--    2136                 info,
--    2137                 status.message,
--    2138                 self._fetch_enriched_error(info),
--    2139                 self._display_server_stack_trace(),
--    2140             ) from None
--    2142     raise SparkConnectGrpcException(
--    2143         message=status.message,
--    2144         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
--    2145     ) from None
--    2146 else:
--
-- AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `emp1` cannot be found. Verify the spelling and correctness of the schema and catalog.
-- Search path: [`system`.`session`, `system`.`builtin`, `system`.`ai`, `sql_catalog`.`sql_schema`].
-- If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
-- To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01; line 3 pos 48;
-- 'Project [*]
-- +- 'Filter sal#15126 IN (list#15112 [])
--    :  +- 'Project ['sal]
--    :     +- 'UnresolvedRelation [emp1], [], false
--    +- SubqueryAlias sql_catalog.sql_schema.emp
--       +- Relation sql_catalog.sql_schema.emp[empno#15121,ename#15122,job#15123,mgr#15124,hiredate#15125,sal#15126,comm#15127,deptno#15128] parquet
--
--
-- JVM stacktrace:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException
-- 	at org.apache.spark.sql.errors.QueryCompilationErrors$.tableOrViewNotFoundWithSearchPath(QueryCompilationErrors.scala:1662)
-- 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.tableNotFound(package.scala:97)
-- 	at org.apache.spark.sql.catalyst.analysis.RelationResolution$.throwTableNotFound(RelationResolution.scala:2064)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:492)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:436)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:406)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:405)
-- 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:405)
-- 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:436)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:403)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:718)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkSubqueryExpression(CheckAnalysis.scala:1510)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkSubqueryExpression$(CheckAnalysis.scala:1506)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkSubqueryExpression(Analyzer.scala:718)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$16(CheckAnalysis.scala:799)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$16$adapted(CheckAnalysis.scala:683)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.traverse$1(CheckAnalysis.scala:1489)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$foreachUpSkippingSecureView$1(CheckAnalysis.scala:1488)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$foreachUpSkippingSecureView$1$adapted(CheckAnalysis.scala:1488)
-- 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.traverse$1(CheckAnalysis.scala:1488)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.foreachUpSkippingSecureView(CheckAnalysis.scala:1491)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$15(CheckAnalysis.scala:683)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$15$adapted(CheckAnalysis.scala:683)
-- 	at scala.collection.IterableOnceOps.foreach(IterableOnce.scala:630)
-- 	at scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:628)
-- 	at scala.collection.AbstractIterable.foreach(Iterable.scala:936)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:683)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:436)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:406)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:405)
-- 	at scala.collection.immutable.Vector.foreach(Vector.scala:2125)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:405)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:436)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:403)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:718)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:388)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:375)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:371)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:718)
-- 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$resolveInFixedPoint$1(HybridAnalyzer.scala:402)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:297)
-- 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.resolveInFixedPoint(HybridAnalyzer.scala:402)
-- 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$apply$1(HybridAnalyzer.scala:94)
-- 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.withTrackedAnalyzerBridgeState(HybridAnalyzer.scala:131)
-- 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.apply(HybridAnalyzer.scala:87)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.runAnalysis$1(Analyzer.scala:781)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$3(Analyzer.scala:786)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.runWithSessionConf(Analyzer.scala:852)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:786)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:448)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:786)
-- 	at com.databricks.sql.unity.SAMSnapshotHelper$.visitPlansDuringAnalysis(SAMSnapshotHelper.scala:43)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:776)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$4(QueryExecution.scala:850)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.measureRule(QueryPlanningTracker.scala:514)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.recordLatency(QueryPlanningTracker.scala:523)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$3(QueryExecution.scala:851)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1256)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:1417)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:382)
-- 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:251)
-- 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:290)
-- 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:87)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:363)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:1417)
-- 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:2268)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:1408)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:1405)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:1405)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:1404)
-- 	at com.databricks.sql.history.ultron.PredictionBackendBatching$.$anonfun$withBatchedUpdates$1(ObservationBuffer.scala:484)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at com.databricks.sql.history.ultron.PredictionBackendBatching$.withBatchedUpdates(ObservationBuffer.scala:484)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$3(QueryExecution.scala:1384)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.localBlock$1(QueryExecution.scala:1383)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$5(QueryExecution.scala:1395)
-- 	at com.databricks.unity.UCSManager$.withTemporaryScope(UCSManager.scala:168)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$withQueryExecutionId$4(QueryExecution.scala:1394)
-- 	at org.apache.spark.sql.execution.QueryExecution$.$anonfun$runWithWrappers$2(QueryExecution.scala:2523)
-- 	at org.apache.spark.sql.execution.QueryExecution$.org$apache$spark$sql$execution$QueryExecution$$runWithWrappers(QueryExecution.scala:2522)
-- 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:1395)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:1403)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:1402)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$2(QueryExecution.scala:842)
-- 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$1(QueryExecution.scala:841)
-- 	at scala.util.Try$.apply(Try.scala:217)
-- 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1797)
-- 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1847)
-- 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:78)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$analyzed$1(QueryExecution.scala:967)
-- 	at org.apache.spark.sql.execution.QueryExecution.withAbortTransactionOnFailure(QueryExecution.scala:1792)
-- 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:967)
-- 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:727)
-- 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:156)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1342)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1342)
-- 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:148)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$6(SparkSession.scala:1016)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:981)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:4502)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:4292)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3856)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:546)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$15(ExecuteThreadRunner.scala:437)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.connect.execution.SparkConnectUdfRejectionScope$.withExecutionSideEffectScope(SparkConnectUdfRejectionScope.scala:31)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:436)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:345)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:913)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:913)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:912)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:345)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:201)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:102)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:99)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:62)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:193)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:617)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:70)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:617)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:128)
-- 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:133)
-- 	at scala.util.Using$.resource(Using.scala:296)
-- 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:132)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:616)

-- %%
--2- ¾ Sal of any Mgr of EMP2 table.

select * from emp where sal in (select sal*.0.75 from emp2 where job = 'MANAGER')
-- Out:
-- ---------------------------------------------------------------------------
-- ParseException                            Traceback (most recent call last)
-- File <command-8586481273662127>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', "--2- ¾ Sal of any Mgr of EMP2 table.\n\nselect * from emp where sal in (select sal*.0.75 from emp2 where job = 'MANAGER')\n")
--
-- File /databricks/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:152, in SqlMagic.sql(self, line, cell)
--     148     raise Exception(
--     149         "Cannot run %sql command because spark connect initialization failed and no stacktrace was available."
--     150     )
--     151 if self.use_py4j:
-- --> 152     return self.execute_via_py4j(cell)
--     154 return self.execute_via_sql_comm_handler(cell)
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:237, in SqlMagic.execute_via_py4j(self, cell)
--     234 except BaseException as e:
--     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     236                                                        json.dumps(get_debug_info(e)))
-- --> 237     raise e
--     238 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
--     239 return result
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:233, in SqlMagic.execute_via_py4j(self, cell)
--     231         print(f"Executing subquery: {query_text}.", file=sys.__stdout__)  # type: ignore
--     232         sql_directive = self.entry_point.getSqlDirective(query_text)
-- --> 233         result = self.handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
--     234 except BaseException as e:
--     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     236                                                        json.dumps(get_debug_info(e)))
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:257, in SqlMagic.handle_sql_directive(self, sql_directive, is_last_query)
--     254 query = sql_directive.sql()
--     255 self._register_udf_if_needed(
--     256     query, self.entry_point.escapeWidgetValues(self.dbutils.widgets.getAll()))
-- --> 257 df = self.get_query_request_result(query)
--     258 if df is None or len(df.schema) == 0:
--     259     # E.g. "create or replace temp view abc as select 1" gets us here and we should not return a result in this case.
--     260     return None
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:129, in SqlMagic.get_query_request_result(self, query)
--     127 if len(widget_bindings := self.dbutils.widgets.getAll()) > 0:
--     128     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
-- --> 129 df = self.asserting_spark.sql(query, widget_bindings)
--     130 return df
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/session.py:736, in SparkSession.sql(self, sqlQuery, args, **kwargs)
--     733         _views.append(SubqueryAlias(df._plan, name))
--     735 cmd = SQL(sqlQuery, _args, _named_args, _views)
-- --> 736 data, properties, ei = self.client.execute_command(cmd.command(self._client))
--     737 if "sql_command_result" in properties:
--     738     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1306, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
--    1304     req.user_context.user_id = self._user_id
--    1305 req.plan.command.CopyFrom(command)
-- -> 1306 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
--    1307     req, observations or {}, extra_request_metadata
--    1308 )
--    1309 # Create a query execution object.
--    1310 ei = ExecutionInfo(metrics, observed_metrics)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1762, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
--    1759 properties: Dict[str, Any] = {}
--    1761 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
-- -> 1762     for response in self._execute_and_fetch_as_iterator(
--    1763         req, observations, extra_request_metadata or [], progress=progress
--    1764     ):
--    1765         if isinstance(response, StructType):
--    1766             schema = response
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1738, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
--    1736     raise kb
--    1737 except Exception as error:
-- -> 1738     self._handle_error(error)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2054, in SparkConnectClient._handle_error(self, error)
--    2052 self.thread_local.inside_error_handling = True
--    2053 if isinstance(error, grpc.RpcError):
-- -> 2054     self._handle_rpc_error(error)
--    2055 elif isinstance(error, ValueError):
--    2056     if "Cannot invoke RPC" in str(error) and "closed" in str(error):
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2135, in SparkConnectClient._handle_rpc_error(self, rpc_error)
--    2131             d.Unpack(info)
--    2133             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
-- -> 2135             raise convert_exception(
--    2136                 info,
--    2137                 status.message,
--    2138                 self._fetch_enriched_error(info),
--    2139                 self._display_server_stack_trace(),
--    2140             ) from None
--    2142     raise SparkConnectGrpcException(
--    2143         message=status.message,
--    2144         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
--    2145     ) from None
--    2146 else:
--
-- ParseException:
-- [PARSE_SYNTAX_ERROR] Syntax error at or near '.75'. SQLSTATE: 42601 (line 3, pos 45)
--
-- == SQL ==
-- --2- ¾ Sal of any Mgr of EMP2 table.
--
-- select * from emp where sal in (select sal*.0.75 from emp2 where job = 'MANAGER')
-- ---------------------------------------------^^^
--
--
-- JVM stacktrace:
-- org.apache.spark.sql.catalyst.parser.ParseException
-- 	at org.apache.spark.sql.catalyst.parser.ParseException.withCommand(parsers.scala:528)
-- 	at org.apache.spark.sql.catalyst.parser.AbstractParser$.executeWithTwoStageStrategy(parsers.scala:342)
-- 	at org.apache.spark.sql.catalyst.parser.AbstractParser.parse(parsers.scala:89)
-- 	at org.apache.spark.sql.execution.SparkSqlParser.super$parse(SparkSqlParser.scala:344)
-- 	at org.apache.spark.sql.execution.SparkSqlParser.$anonfun$parseInternal$1(SparkSqlParser.scala:344)
-- 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:142)
-- 	at org.apache.spark.sql.execution.SparkSqlParser.parseInternal(SparkSqlParser.scala:344)
-- 	at org.apache.spark.sql.execution.SparkSqlParser.parseWithParameters(SparkSqlParser.scala:193)
-- 	at org.apache.spark.sql.execution.SparkSqlParser.parsePlanWithParameters(SparkSqlParser.scala:207)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$9(SparkSession.scala:995)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:297)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$8(SparkSession.scala:995)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:201)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:1256)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$6(SparkSession.scala:991)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:981)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:4502)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:4292)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3856)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:546)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$15(ExecuteThreadRunner.scala:437)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.connect.execution.SparkConnectUdfRejectionScope$.withExecutionSideEffectScope(SparkConnectUdfRejectionScope.scala:31)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:436)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:345)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:913)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:866)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:913)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:912)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:345)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:201)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:102)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:99)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:62)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:193)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:617)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:70)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:617)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:128)
-- 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:133)
-- 	at scala.util.Using$.resource(Using.scala:296)
-- 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:132)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:616)

-- %%
--3- The sal of any person with exp of 5 years belongs to the sales dept of emp3 table.

SELECT * from emp 
where sal in (select sal from emp e3 join dept d on e3.deptno = d.deptno
where d.dname = 'SALES' and (year(current_date) - year(hiredate) >= 5));
/*
or

SELECT * from emp where sal in (select sal from emp e3 join dept d on e3.deptno = d.deptno
where d.dname = 'SALES' and datediff(current_date(), e.hiredate)/365>=5)

*/
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-02-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839</td><td>1981-05-01</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-09-08</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr></tbody></table></div>

-- %%
--4- Any grade 2 employee of emp4 table.

select * from emp 
where sal in (select e.sal from emp e join salgrade s on e.sal between s.losal and s.hisal where s.grade = 2);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-02-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-09-28</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

-- %%
--5- Any grade 2 and 3 employee working from sales dept or operations dept joined in 89.

select * from emp where sal in(select e.sal from emp e join dept d on e.deptno = d.deptno
join salgrade s on e.sal between s.losal and s.hisal where s.grade in (2,3)
and d.dname in ('sales'));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ####  2.60.	Any	jobs	of	deptno	10	those	that	are	not	found	in	deptno	20.

-- %%
select job from emp where deptno = 10 
except
select job from emp where deptno = 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>job</th></tr></thead><tbody><tr><td>PRESIDENT</td></tr></tbody></table></div>
